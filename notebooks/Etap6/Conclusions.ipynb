# %%
import skimage.io as io
from pathlib import Path
import matplotlib.pyplot as plt

# %% [markdown]
# ## RFC_allFeatures

# %%
path = Path('Shap_plots/RFC_allFeatures/')

# %% [markdown]
# #### *desc_capital_letters_percent* - jakieś 15% wielkich liter w opisie, czyli jakieś ważne słowa/frazy pisać wielkimi literami

# %%
plt.figure(dpi=100)
plt.axis('off')

img = io.imread(str(path) + '/dependency_desc_capital_letters_percent.png')
io.imshow(img)

# %% [markdown]
# #### *desc_length* - 300-1500 znaków

# %%
plt.figure(dpi=100)
plt.axis('off')

img = io.imread(str(path) + '/dependency_desc_length.png')
io.imshow(img)

# %% [markdown]
# #### *desc_n_of_words* - powyżej 100 wyrazów

# %%
plt.figure(dpi=100)
plt.axis('off')

img = io.imread(str(path) + '/dependency_desc_n_of_words.png')
io.imshow(img)

# %% [markdown]
# #### *desc_punctuation* - od 0 do 20 znaków interpunkcyjnych, nie przesadzać z wykrzyknikami itd. krótsze opisy

# %%
plt.figure(dpi=100)
plt.axis('off')

img = io.imread(str(path) + '/dependency_desc_punctuation.png')
io.imshow(img)

# %% [markdown]
# #### *desc_small_letters_percent* - minimum 60% małych liter, ale lepiej więcej

# %%
plt.figure(dpi=100)
plt.axis('off')

img = io.imread(str(path) + '/dependency_desc_small_letters_percent.png')
io.imshow(img)

# %% [markdown]
# #### *likes/views* - im więcej tym lepiej

# %%
plt.figure(dpi=100)
plt.axis('off')

img = io.imread(str(path) + '/dependency_likes-views.png')
io.imshow(img)

# %% [markdown]
# #### *n_of_tags* - dawać tagi

# %%
plt.figure(dpi=100)
plt.axis('off')

img = io.imread(str(path) + '/dependency_n_of_tags.png')
io.imshow(img)

# %% [markdown]
# #### *ocr_sentiment_compound* - napisy na thumbnailach nie powinny posiadać zbyt wiele emocji

# %%
plt.figure(dpi=100)
plt.axis('off')

img = io.imread(str(path) + '/dependency_ocr_sentiment_compound.png')
io.imshow(img)

# %% [markdown]
# #### *pub_hour* - najlepiej między 7-17, nie wrzucać filmów w nocy

# %%
plt.figure(dpi=100)
plt.axis('off')

img = io.imread(str(path) + '/dependency_pub_hour.png')
io.imshow(img)

# %% [markdown]
# #### *title_capital_letters_percent* - do 20%, nie pisać całych z wielkich liter

# %%
plt.figure(dpi=100)
plt.axis('off')

img = io.imread(str(path) + '/dependency_title_capital_letters_percent.png')
io.imshow(img)

# %% [markdown]
# #### *title_length* - 15-30 znaków w tytule

# %%
plt.figure(dpi=100)
plt.axis('off')

img = io.imread(str(path) + '/dependency_title_length.png')
io.imshow(img)

# %% [markdown]
# #### *title_punctuation* - mało, nie przesadzać, do 5%

# %%
plt.figure(dpi=100)
plt.axis('off')

img = io.imread(str(path) + '/dependency_title_punctuation.png')
io.imshow(img)

# %% [markdown]
# #### *tile_small_letters_percent* - 60-80%

# %%
plt.figure(dpi=100)
plt.axis('off')

img = io.imread(str(path) + '/dependency_title_small_letters_percent.png')
io.imshow(img)

# %% [markdown]
# #### *avg_texts_coordX-avg_texts_coordY* napisy w thumbnailach dawać w dolnym lewym rogu

# %%
plt.figure(dpi=100)
plt.axis('off')

img = io.imread('Shap_plots/custom/RFC_allFeatures/dependency_avg_texts_coordX-avg_texts_coordY.png')
io.imshow(img)

# %% [markdown]
# #### *mean_v-std_v* - value w HSV powinno być około 0.2 czyli ciemne kolory i nie powinno być dużej różnorodności, niski kontrast?

# %%
plt.figure(dpi=100)
plt.axis('off')

img = io.imread('Shap_plots/custom/RFC_allFeatures/dependency_mean_v-std_v.png')

io.imshow(img)

# %% [markdown]
# ## LogisticRegression

# %%
path = Path('Shap_plots/LogisticRegression_allFeatures/')

# %% [markdown]
# #### *desc_n_of_urls* - im więcej tym lepiej url

# %%
plt.figure(dpi=100)
plt.axis('off')

img = io.imread(str(path) + '/dependency_desc_n_of_urls.png')
io.imshow(img)

# %% [markdown]
# #### *ocr_sentiment_compound*  -  lepiej negatywne niż pozytywne słowa w thumbnailach?

# %%
plt.figure(dpi=100)
plt.axis('off')

img = io.imread(str(path) + '/dependency_ocr_sentiment_compound.png')
io.imshow(img)

# %% [markdown]
# #### *people* - im więcej ludzi na thumbnailu tym lepiej

# %%
plt.figure(dpi=100)
plt.axis('off')

img = io.imread(str(path) + '/dependency_people.png')
io.imshow(img)

# %% [markdown]
# ## MLP

# %%
path = Path('Shap_plots/MLP_all/')

# %% [markdown]
# #### *desc_capital_letters_percent* - tak powyżej 15%

# %%
plt.figure(dpi=100)
plt.axis('off')

img = io.imread(str(path) + '/dependency_desc_capital_letters_percent.png')
io.imshow(img)

# %% [markdown]
# #### *desc_n_of_emojis* - może być kilka

# %%
plt.figure(dpi=100)
plt.axis('off')

img = io.imread(str(path) + '/dependency_desc_n_of_emojis.png')
io.imshow(img)

# %% [markdown]
# #### *title_n_of_words* - poniżej 10 słów w tytule

# %%
plt.figure(dpi=100)
plt.axis('off')

img = io.imread(str(path) + '/dependency_title_n_of_words.png')
io.imshow(img)
