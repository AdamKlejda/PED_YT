# %%
import pandas as pd

# %% [markdown]
# ### Dla Etapu 3

# %%
dfLilate2 = pd.read_csv("./../../../our_data/Etap5/Etap2/Etap2LiLatee.csv")
dfAdam2= pd.read_csv("./../../../our_data/Etap5/Etap2/adam/df_finall.csv")
# Out:
# /home/adam/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (16) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
dfAdam2
# Out:
#                                                emotions           id  \
# 0                                                    []  tOpTQ3Fuf9s
# 1                                                    []  k0DqRstCgj4
# 2                                                    []  1CYH4F1KCw8
# 3                                                    []  UdjEoGzXxmI
# 4                  ['Sad', 'Sad', 'Neutral', 'Neutral']  cD8SYW8rjaQ
# ...                                                 ...          ...
# 6501  ['Sad', 'Angry', 'Angry', 'Neutral', 'Angry', ...  WBIlusTGa5w
# 6502                                                 []  eXjCcC7e1fk
# 6503                                            ['Sad']  ganP0dyR3GI
# 6504                                                 []  PDti1FMjPmA
# 6505                                 ['Happy', 'Angry']  r4DD6ZrZ3_4
#
#                                              categories  \
# 0     [['stretcher', 0.09478817], ['prison', 0.08772...
# 1     [['theater curtain', 0.47661874], ['stage', 0....
# 2     [['planetarium', 0.2688136], ['military unifor...
# 3     [['radio telescope', 0.107818], ['jean', 0.096...
# 4     [['sports car', 0.4145472], ['racer', 0.392479...
# ...                                                 ...
# 6501  [['coho', 0.08500227], ['barracouta', 0.080164...
# 6502  [['stage', 0.84550816], ['theater curtain', 0....
# 6503  [['torch', 0.40831023], ['ski', 0.05857353], [...
# 6504  [['book jacket', 0.19738354], ['cash machine',...
# 6505  [['burrito', 0.22436675], ['spaghetti squash',...
#
#                                                 objects  Sad  Fear  Angry  \
# 0     [['person', 0.9170731902122498], ['person', 0....    0     0      0
# 1     [['person', 0.954002857208252], ['person', 0.4...    0     0      0
# 2     [['person', 0.9589637517929077], ['person', 0....    0     0      0
# 3     [['person', 0.9621104001998901], ['person', 0....    0     0      0
# 4     [['person', 0.9145326018333435], ['person', 0....    2     0      0
# ...                                                 ...  ...   ...    ...
# 6501  [['person', 0.9805687069892883], ['person', 0....    3     1      4
# 6502  [['person', 0.2859192490577698], ['person', 0....    0     0      0
# 6503  [['person', 0.6036699414253235], ['suitcase', ...    1     0      0
# 6504  [['person', 0.8915494680404663], ['person', 0....    0     0      0
# 6505  [['person', 0.5744277834892273], ['person', 0....    0     0      1
#
#       Happy  Neutral  Surprise  \
# 0         0        0         0
# 1         0        0         0
# 2         0        0         0
# 3         0        0         0
# 4         0        2         0
# ...     ...      ...       ...
# 6501      1        2         0
# 6502      0        0         0
# 6503      0        0         0
# 6504      0        0         0
# 6505      1        0         0
#
#                                         categories_list  \
# 0     ['stretcher', 'prison', 'bearskin', 'suit', 't...
# 1     ['theater curtain', 'stage', 'barn', 'prison',...
# 2     ['planetarium', 'military uniform', 'cinema', ...
# 3     ['radio telescope', 'jean', 'cellular telephon...
# 4     ['sports car', 'racer', 'cab', 'car wheel', 'p...
# ...                                                 ...
# 6501  ['coho', 'barracouta', 'suit', 'bulletproof ve...
# 6502  ['stage', 'theater curtain', 'spotlight', 'tor...
# 6503  ['torch', 'ski', 'tennis ball', 'sax', 'microp...
# 6504  ['book jacket', 'cash machine', 'television', ...
# 6505  ['burrito', 'spaghetti squash', 'plate', 'head...
#
#                                             object_list  people  faces
# 0     ['person', 'person', 'person', 'person', 'pers...      25    0.0
# 1     ['person', 'person', 'cell phone', 'cell phone...       8    0.0
# 2     ['person', 'person', 'person', 'person', 'pers...      14    0.0
# 3     ['person', 'person', 'person', 'person', 'pers...      11    0.0
# 4     ['person', 'person', 'car', 'person', 'person'...      12    4.0
# ...                                                 ...     ...    ...
# 6501  ['person', 'person', 'person', 'person', 'pers...      16   11.0
# 6502  ['person', 'person', 'person', 'person', 'pers...      60    0.0
# 6503  ['person', 'suitcase', 'skis', 'bicycle', 'car...       5    1.0
# 6504  ['person', 'person', 'person', 'person', 'pers...      19    0.0
# 6505       ['person', 'person', 'dining table', 'bowl']       2    2.0
#
# [6506 rows x 14 columns]

# %%
df_finall = dfLilate2.merge(dfAdam2, how='outer', left_on='video_id', right_on='id')
df_finall = df_finall.drop(['id'], axis=1)
df_finall.to_csv("./../../../our_data/Etap5/Etap2/df_merged.csv",index=False)

# %%
list(df_finall.columns)
# Out:
# ['video_id',
#  'trending_date',
#  'title',
#  'channel_title',
#  'category_id',
#  'publish_time',
#  'tags',
#  'views',
#  'likes',
#  'dislikes',
#  'comment_count',
#  'thumbnail_link',
#  'comments_disabled',
#  'ratings_disabled',
#  'video_error_or_removed',
#  'description',
#  'relatedTo',
#  'pub_date',
#  'pub_day_of_the_week',
#  'pub_year',
#  'pub_month',
#  'pub_day',
#  'pub_hour',
#  'tren_date',
#  'tren_day_of_the_week',
#  'tren_year',
#  'tren_month',
#  'tren_day',
#  'time_to_trend_in_days',
#  'dislikes/likes',
#  'likes/views',
#  'dislikes/views',
#  'comment_count/views',
#  'increase_views',
#  'increase_likes',
#  'increase_dislikes',
#  'increase_comms',
#  'times_in_trend',
#  'avg_views',
#  'avg_likes',
#  'avg_dislikes',
#  'avg_comms',
#  'avg_views_increase_per_hour',
#  'n_of_tags',
#  'title_clean',
#  'title_length',
#  'title_n_of_words',
#  'title_capital_letters',
#  'title_capital_letters_percent',
#  'title_small_letters',
#  'title_small_letters_percent',
#  'title_punctuation',
#  'title_punctuation_percent',
#  'title_n_of_emojis',
#  'desc_clean',
#  'desc_length',
#  'desc_n_of_words',
#  'desc_capital_letters',
#  'desc_capital_letters_percent',
#  'desc_small_letters',
#  'desc_small_letters_percent',
#  'desc_punctuation',
#  'desc_punctuation_percent',
#  'desc_list_of_urls',
#  'desc_n_of_urls',
#  'desc_n_of_emojis',
#  'isFacebook',
#  'isTwitter',
#  'isInstagram',
#  'mean_r',
#  'mean_g',
#  'mean_b',
#  'std_r',
#  'std_g',
#  'std_b',
#  'hist_r',
#  'hist_g',
#  'hist_b',
#  'mean_h',
#  'mean_s',
#  'mean_v',
#  'std_h',
#  'std_s',
#  'std_v',
#  'entropy',
#  'thumb_ocr_text',
#  'clean_thumb_ocr_text',
#  'thumb_ocr_text_V2',
#  'clean_thumb_ocr_text_V2',
#  'bboxes',
#  'avg_texts_coords',
#  'avg_texts_coordX',
#  'avg_texts_coordY',
#  'ocr_sentiment_compound',
#  'emotions',
#  'categories',
#  'objects',
#  'Sad',
#  'Fear',
#  'Angry',
#  'Happy',
#  'Neutral',
#  'Surprise',
#  'categories_list',
#  'object_list',
#  'people',
#  'faces']

# %%
# br_et3
dfUS_finall = us_et3.merge(dfUS, how='outer', left_on='video_id', right_on='id')
# dfGb_finall = dfGb_finall.merge(dfGb1, how='inner', left_on='video_id', right_on='video_id')
# dfUS_finall = dfUS_finall.merge(dfUS1, how='inner', left_on='video_id', right_on='video_id')
listaUS = dfUS_finall.loc[:, "video_id"].values


df_gb1 = dfGb1.loc[~dfGb1.video_id.isin(listaGb), :]
df_us1 = dfUS1.loc[~dfUS1.video_id.isin(listaUS), :]

dfGb_finall = pd.concat([df_gb1,dfGb_finall])
dfUS_finall = pd.concat([df_us1,dfUS_finall])


dfUS_finall = dfUS_finall.drop(['id'], axis=1)
dfUS_finall = dfUS_finall.loc[~dfUS_finall.video_id.isna(), :]
dfUS_finall = dfUS_finall.groupby(['video_id']).first()
dfUS_finall = dfUS_finall.loc[:, dfUS_finall.columns != "Unnamed: 0"]
dfUS_finall = dfUS_finall.reset_index()

dfGb_finall = dfGb_finall.drop(['id'], axis=1)
dfGb_finall = dfGb_finall.loc[~dfGb_finall.video_id.isna(), :]
dfGb_finall = dfGb_finall.groupby(['video_id']).first()
dfGb_finall = dfGb_finall.loc[:, dfGb_finall.columns != "Unnamed: 0"]
dfGb_finall = dfGb_finall.reset_index()
# print(result.shape) 
dfGb_finall.to_csv("../our_data/Etap3/GB_merged.csv",index=False)

dfUS_finall.to_csv("../our_data/Etap3/US_merged.csv",index=False)

# %%
# br_et3
dfGb_finall = br_et3.merge(dfGb, how='outer', left_on='video_id', right_on='id')
dfUS_finall = us_et3.merge(dfUS, how='outer', left_on='video_id', right_on='id')
# dfGb_finall = dfGb_finall.merge(dfGb1, how='inner', left_on='video_id', right_on='video_id')
# dfUS_finall = dfUS_finall.merge(dfUS1, how='inner', left_on='video_id', right_on='video_id')
listaGb = dfGb_finall.loc[:, "video_id"].values
listaUS = dfUS_finall.loc[:, "video_id"].values


df_gb1 = dfGb1.loc[~dfGb1.video_id.isin(listaGb), :]
df_us1 = dfUS1.loc[~dfUS1.video_id.isin(listaUS), :]

dfGb_finall = pd.concat([df_gb1,dfGb_finall])
dfUS_finall = pd.concat([df_us1,dfUS_finall])


dfUS_finall = dfUS_finall.drop(['id'], axis=1)
dfUS_finall = dfUS_finall.loc[~dfUS_finall.video_id.isna(), :]
dfUS_finall = dfUS_finall.groupby(['video_id']).first()
dfUS_finall = dfUS_finall.loc[:, dfUS_finall.columns != "Unnamed: 0"]
dfUS_finall = dfUS_finall.reset_index()

dfGb_finall = dfGb_finall.drop(['id'], axis=1)
dfGb_finall = dfGb_finall.loc[~dfGb_finall.video_id.isna(), :]
dfGb_finall = dfGb_finall.groupby(['video_id']).first()
dfGb_finall = dfGb_finall.loc[:, dfGb_finall.columns != "Unnamed: 0"]
dfGb_finall = dfGb_finall.reset_index()
# print(result.shape) 
dfGb_finall.to_csv("../our_data/Etap2/GB_merged.csv",index=False)

dfUS_finall.to_csv("../our_data/Etap2/US_merged.csv",index=False)

# %%
br_et3 = pd.read_csv("../our_data/Etap2/GB-Etap2.csv")
us_et3 = pd.read_csv("../our_data/Etap2/US-Etap2.csv")
dfGb= pd.read_csv("../our_data/Etap2/adam/dfGB_finall.csv")
dfUS= pd.read_csv("../our_data/Etap2/adam/dfUS_finall.csv")

dfGb1= pd.read_csv("../our_data/Etap1/GB.csv")
dfUS1= pd.read_csv("../our_data/Etap1/US.csv")

# %% [markdown]
# ### Dla Etapu 2
